# %% [markdown]
# # Homework 14
# ## Mapping Part 2 : Group 2
#
# ### Kate Cough
# ### Due: July 15 2017

# %%
import pandas as pd
import geopandas as gpd
from shapely.geometry import Point
import matplotlib.pyplot as plt
import pysal as ps


# %matplotlib inline

# %%
powerplants = pd.read_csv('/Users/kaitlincough/Documents/Lede/foundation/14-homework-powerplants/powerplants.csv')
powerplants.head(2)

# %%
#import the files we need and look at them. just powerplants for now.
powerplants = pd.read_csv('/Users/kaitlincough/Documents/Lede/foundation/14-homework-powerplants/powerplants.csv')
#apply the function to each row of powerplants to turn it into a geodatafram
points = powerplants.apply(lambda row: Point(row.Longitude, row.Latitude), axis=1)
#actually make it a geodataframe
powerplants = gpd.GeoDataFrame(powerplants, geometry=points)
#set the crs so we're not sad later
powerplants.crs = {'init':'epsg:5070'}
powerplants.head(2)

# %%
#always a good idea to plot it, just to see right. 
#and to make it not totally awful so our eyes don't burn
#alpha is for opacity, markeredgewidth and sizes are just 
#to change the dot sizes
#keep the axis for now so we can see the lat/long

powerplants.plot(figsize=(20,10), color='#3498DB', markeredgewidth=0, markersize=5, alpha=0.5)

# %% [markdown]
# Lesson: there are a LOT of powerplants in the US.

# %%
#let's plot it without the axis and set the x,y limits
#so we can just focus on the continental us
ax = powerplants.plot(figsize=(20,10), color='#3498DB', markeredgewidth=0, markersize=5, alpha=0.5)
# ax.axis('off')

#set the limits so it stays within these lat/long.
#we know the limits we want to use by looking at the map above
ax.set_xlim([-130,-60])
ax.set_ylim([25,50])

# %%
#import the shape file. remember it's reading EVERYTHING in the folder, not just the .shp
#but we only import the .shp

states = gpd.read_file('/Users/kaitlincough/Documents/Lede/foundation/14-homework-powerplants/cb_2016_us_state_500k/cb_2016_us_state_500k.shp')
#change the crs to match the one above, use the conus albers one
#which is good for the united states but sad for other places
states.crs = {'init':'epsg:5070'}
states.head(2)

# %%
#plot the states, turn off the axis, make the colors not horrendous

ax = states.plot(figsize=(20,10), color='lightgrey', edgecolor='white')
# ax.axis('off')

# %%
ax = states.plot(figsize=(20,10), color='lightgrey', edgecolor='white')
powerplants.plot(figsize=(20,10), ax=ax, color='#3498DB', markeredgewidth=0, markersize=5, alpha=0.5)
ax.set_xlim([-130,-60])
ax.set_ylim([25,50])
# ax.axis('off')

# %%
#we need this file with the air quality monitoring info

airqual = pd.read_csv('/Users/kaitlincough/Documents/Lede/foundation/14-homework-powerplants/annual_conc_by_monitor_2017.csv')
airqual.head(2)

# %%
#turn the airqual into a geodataframe 
#read in only useful columns

airqual = pd.read_csv('/Users/kaitlincough/Documents/Lede/foundation/14-homework-powerplants/pm25_annual_fixed.csv', usecols = ['Latitude', 'Longitude', 'Datum', 'Arithmetic Mean', '1st Max Value', 'State Name', 'County Name', 'City Name'])
points = airqual.apply(lambda row: Point(row.Longitude, row.Latitude), axis=1)
airqual = gpd.GeoDataFrame(airqual, geometry=points)
airqual.crs = {'init':'epsg:5070'}
airqual.head()

# %% [markdown]
# # GROUP TWO: For most of these you'll need a spatial join

# %% [markdown]
# ## 1. How many power plants are in each state?

# %%
#first we need a dataframe with the geometry of the
#states and the powerplants
#by having powerplants first after sjoin
#we keep the geometry of powerplants (ie the points not the polygons)
#inner is saying get rid of values w/o a match

plants_with_states = gpd.sjoin(powerplants, states, how='inner', op='within')
plants_with_states.head(2)
# Out:
#    Plant_Code    Plant_Name        Utility_Na  Utility_ID        sector_nam  \
# 0           2  Bankhead Dam  Alabama Power Co         195  Electric Utility
# 1           3         Barry  Alabama Power Co         195  Electric Utility
#
#         City      County    Zip          Street_Add     PrimSource   ...    \
# 0  Northport  Tuscaloosa  35476  19001 Lock 17 Road  hydroelectric   ...
# 1      Bucks      Mobile  36512    North Highway 43           coal   ...
#
#    index_right     AFFGEOID         ALAND      AWATER  GEOID  LSAD     NAME  \
# 0            0  0400000US01  131173688951  4593686489     01    00  Alabama
# 1            0  0400000US01  131173688951  4593686489     01    00  Alabama
#
#    STATEFP   STATENS  STUSPS
# 0       01  01779775      AL
# 1       01  01779775      AL
#
# [2 rows x 39 columns]

# %%
plants_with_states['NAME'].value_counts().head()
# Out:
# California        1222
# North Carolina     461
# Texas              396
# New York           372
# Minnesota          274
# Name: NAME, dtype: int64

# %% [markdown]
# ## 2. Which power plants are in New York?

# %%
plants_with_states[(plants_with_states['NAME'] == 'New York')]
# Out:
#       Plant_Code                           Plant_Name  \
# 49            88                              Ashokan
# 363          579            Central Hudson High Falls
# 387          625                  Upper Mechanicville
# 469          808                    Jarvis (Hinckley)
# 1169        2480        Danskammer Generating Station
# 1170        2481                            Dashville
# 1171        2483                            Neversink
# 1172        2485                          South Cairo
# 1173        2486                             Sturgeon
# 1174        2487                       West Coxsackie
# 1175        2490       Arthur Kill Generating Station
# 1176        2493                           East River
# 1177        2494      Gowanus Gas Turbines Generating
# 1178        2496                        Hudson Avenue
# 1179        2497                       Indian Point 2
# 1180        2499      Narrows Gas Turbines Generating
# 1181        2500                           Ravenswood
# 1182        2503                          59th Street
# 1183        2504                          74th Street
# 1184        2511                          E F Barrett
# 1185        2512                         East Hampton
# 1186        2514                             Glenwood
# 1187        2516                            Northport
# 1188        2517                       Port Jefferson
# 1189        2518                             Shoreham
# 1190        2519                        South Hampton
# 1191        2520                             Southold
# 1192        2521                         West Babylon
# 1193        2522                            Cadyville
# 1194        2527             Greenidge Generation LLC
# ...          ...                                  ...
# 6617       58785                      Brentwood Solar
# 6618       58786                            Deer Park
# 6619       58787                             Dennison
# 6620       58788                         North County
# 6621       58789                            Riverhead
# 6622       58790                              Cohalan
# 6643       58815               Hilton NY Co Gen Plant
# 6685       58873                     Stuyvesant Falls
# 6973       59274                 Sutter Greeworks LLC
# 6974       59275           Sterlington Greenworks LLC
# 6975       59276           Leavenworth Greenworks LLC
# 7088       59453       Albany Medical Ctr Cogen Plant
# 7105       59470      Cornell Snyder Road Solar Array
# 7198       59613       Town of Williamson Landfill PV
# 7204       59623                       Clarkson Solar
# 7320       59789                     Millbrook School
# 7338       59816                        Nanticoke LFG
# 7430       60004   Clarkstown Landfill Solar Facility
# 7484       60097  Onondaga County - Metro Water Board
# 7514       60150            Cornell Geneva Solar Farm
# 7571       60365                       Vulcraft Solar
# 7587       60425                     Skidmore College
# 7590       60431  Tompkins Cortland Community College
# 7597       60452                            Calverton
# 7598       60453                         Cummins, Inc
# 7599       60454                             Houghton
# 7600       60455                       Oneida - South
# 7601       60456                        Oneida - West
# 7604       60477                     Bethlehem - East
# 7605       60478                     Bethlehem - West
#
#                              Utility_Na  Utility_ID          sector_nam  \
# 49             New York Power Authority       15296    Electric Utility
# 363      Central Hudson Gas & Elec Corp        3249    Electric Utility
# 387      New York State Elec & Gas Corp       13511    Electric Utility
# 469            New York Power Authority       15296    Electric Utility
# 1169                  Danskammer Energy       58971         IPP Non-CHP
# 363   01779796      NY
# 387   01779796      NY
# 469   01779796      NY
# 1169  01779796      NY
# 1170  01779796      NY
# 1171  01779796      NY
# 1172  01779796      NY
# 1173  01779796      NY
# 1174  01779796      NY
# 1175  01779796      NY
# 1176  01779796      NY
# 1177  01779796      NY
# 1178  01779796      NY
# 1179  01779796      NY
# 1180  01779796      NY
# 1181  01779796      NY
# 1182  01779796      NY
# 1183  01779796      NY
# 1184  01779796      NY
# 1185  01779796      NY
# 1186  01779796      NY
# 1187  01779796      NY
# 1188  01779796      NY
# 1189  01779796      NY
# 1190  01779796      NY
# 1191  01779796      NY
# 1192  01779796      NY
# 1193  01779796      NY
# 1194  01779796      NY
# ...        ...     ...
# 6617  01779796      NY
# 6618  01779796      NY
# 6619  01779796      NY
# 6620  01779796      NY
# 6621  01779796      NY
# 6622  01779796      NY
# 6643  01779796      NY
# 6685  01779796      NY
# 6973  01779796      NY
# 6974  01779796      NY
# 6975  01779796      NY
# 7088  01779796      NY
# 7105  01779796      NY
# 7198  01779796      NY
# 7204  01779796      NY
# 7320  01779796      NY
# 7338  01779796      NY
# 7430  01779796      NY
# 7484  01779796      NY
# 7514  01779796      NY
# 7571  01779796      NY
# 7587  01779796      NY
# 7590  01779796      NY
# 7597  01779796      NY
# 7598  01779796      NY
# 7599  01779796      NY
# 7600  01779796      NY
# 7601  01779796      NY
# 7604  01779796      NY
# 7605  01779796      NY
#
# [372 rows x 39 columns]

# %% [markdown]
# ## 3. Which state has the most hydroelectric power plants?

# %%
hydroelectric = plants_with_states[plants_with_states['PrimSource'].str.contains('hydroelectric')]
hydroelectric['NAME'].value_counts().head(1)
# Out:
# California    245
# Name: NAME, dtype: int64

# %% [markdown]
# ## 4. Which state produces the most energy from coal?

# %%
coal = plants_with_states[plants_with_states['PrimSource'].str.contains('coal')]
coal['NAME'].value_counts().head(1)
# Out:
# Pennsylvania    24
# Name: NAME, dtype: int64

# %% [markdown]
# ## 5. Map states with nuclear power plants in red, and states without in grey. Do the same thing for solar.

# %%
#first, we need to change the join around to keep
#the geometry of the states
#keep things without matches otherwise
#we'll be missing states

states_with_plants = gpd.sjoin(states, powerplants, how='left', op='contains')
states_with_plants.head(2)
# Out:
#       AFFGEOID         ALAND      AWATER GEOID LSAD     NAME STATEFP  \
# 0  0400000US01  131173688951  4593686489    01   00  Alabama      01
# 0  0400000US01  131173688951  4593686489    01   00  Alabama      01
#
#     STATENS STUSPS                                           geometry  \
# 0  01779775     AL  (POLYGON ((-88.053375 30.506987, -88.051087999...
# 0  01779775     AL  (POLYGON ((-88.053375 30.506987, -88.051087999...
#
#      ...     Solar_MW  Wind_MW Geo_MW Other_MW              source_des  \
# 0    ...          0.0      0.0    NaN      NaN  Hydroelectric = 186 MW
# 0    ...          0.0      0.0    NaN      NaN  Natural Gas = 721.8 MW
#
#                           tech_desc                         Source    Period  \
# 0        Conventional Hydroelectric  EIA-860, EIA-860M and EIA-923  201607.0
# 0  Natural Gas Fired Combined Cycle  EIA-860, EIA-860M and EIA-923  201607.0
#
#     Latitude  Longitude
# 0  32.680394 -85.911442
# 0  33.000669 -85.903278
#
# [2 rows x 39 columns]

# %%
#now look for states that have nuclear as their primary source

nuclear = states_with_plants[(states_with_plants['PrimSource'] == 'nuclear')]
# nuclear.plot(color='red')

# %%
non_nuclear = states_with_plants[(states_with_plants['PrimSource'] != 'nuclear')]
# non_nuclear.plot(color='darkgrey')

# %%
ax = states.plot(figsize=(20,20), color = 'lightgray', edgecolor = 'white')
# ax.axis('off')

nuclear.plot(ax=ax, color='red')
non_nuclear.plot(ax=ax, color='darkgrey', alpha=0.5)

ax.set_xlim([-130,-60])
ax.set_ylim([25,50])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-99506738f20e> in <module>()
#       3
#       4 nuclear.plot(ax=ax, color='red')
# ----> 5 non_nuclear.plot(ax=ax, color='darkgrey', alpha=0.5)
#       6
#       7 ax.set_xlim([-130,-60])
#
# /usr/local/lib/python3.6/site-packages/geopandas/geodataframe.py in plot(self, *args, **kwargs)
#     445     def plot(self, *args, **kwargs):
#     446
# --> 447         return plot_dataframe(self, *args, **kwargs)
#     448
#     449     plot.__doc__ = plot_dataframe.__doc__
#
# /usr/local/lib/python3.6/site-packages/geopandas/plotting.py in plot_dataframe(s, column, cmap, color, linewidth, categorical, legend, ax, scheme, k, vmin, vmax, figsize, **color_kwds)
#     238         return plot_series(s.geometry, cmap=cmap, color=color,
#     239                            ax=ax, linewidth=linewidth, figsize=figsize,
# --> 240                            **color_kwds)
#     241     else:
#     242         if s[column].dtype is np.dtype('O'):
#
# /usr/local/lib/python3.6/site-packages/geopandas/plotting.py in plot_series(s, cmap, color, ax, linewidth, figsize, **color_kwds)
#     141                 plot_multipolygon(ax, geom, linewidth=linewidth, **color_kwds)
#     142             else:
# --> 143                 plot_multipolygon(ax, geom, facecolor=col, linewidth=linewidth, **color_kwds)
#     144         elif geom.type == 'LineString' or geom.type == 'MultiLineString':
#     145             plot_multilinestring(ax, geom, color=col, linewidth=linewidth, **color_kwds)
#
# /usr/local/lib/python3.6/site-packages/geopandas/plotting.py in plot_multipolygon(ax, geom, facecolor, edgecolor, alpha, linewidth, **kwargs)
#      31     elif geom.type == 'MultiPolygon':
#      32         for poly in geom.geoms:
# ---> 33             plot_polygon(ax, poly, facecolor=facecolor, edgecolor=edgecolor, alpha=alpha, linewidth=linewidth, **kwargs)
#      34
#      35
#
# /usr/local/lib/python3.6/site-packages/geopandas/plotting.py in plot_polygon(ax, poly, facecolor, edgecolor, alpha, linewidth, **kwargs)
#      18     # without Descartes, we could make a Patch of exterior
#      19     ax.add_patch(PolygonPatch(poly, facecolor=facecolor, linewidth=0, alpha=alpha))  # linewidth=0 because boundaries are drawn separately
# ---> 20     ax.plot(a[:, 0], a[:, 1], color=edgecolor, linewidth=linewidth, **kwargs)
#      21     for p in poly.interiors:
#      22         x, y = zip(*p.coords)
#
# /usr/local/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1896                     warnings.warn(msg % (label_namer, func.__name__),
#    1897                                   RuntimeWarning, stacklevel=2)
# -> 1898             return func(ax, *args, **kwargs)
#    1899         pre_doc = inner.__doc__
#    1900         if pre_doc is None:
#
# /usr/local/lib/python3.6/site-packages/matplotlib/axes/_axes.py in plot(self, *args, **kwargs)
#    1408             lines.append(line)
#    1409
# -> 1410         self.autoscale_view(scalex=scalex, scaley=scaley)
#    1411         return lines
#    1412
#
# /usr/local/lib/python3.6/site-packages/matplotlib/axes/_base.py in autoscale_view(self, tight, scalex, scaley)
#    2264
#    2265         if self.use_sticky_edges and (self._xmargin or self._ymargin):
# -> 2266             stickies = [artist.sticky_edges for artist in self.get_children()]
#    2267             x_stickies = sum([sticky.x for sticky in stickies], [])
#    2268             y_stickies = sum([sticky.y for sticky in stickies], [])
#
# /usr/local/lib/python3.6/site-packages/matplotlib/axes/_base.py in <listcomp>(.0)
#    2264
#    2265         if self.use_sticky_edges and (self._xmargin or self._ymargin):
# -> 2266             stickies = [artist.sticky_edges for artist in self.get_children()]
#    2267             x_stickies = sum([sticky.x for sticky in stickies], [])
#    2268             y_stickies = sum([sticky.y for sticky in stickies], [])
#
# /usr/local/lib/python3.6/site-packages/matplotlib/artist.py in sticky_edges(self)
#     928         self.stale = True
#     929
# --> 930     @property
#     931     def sticky_edges(self):
#     932         """
#
# KeyboardInterrupt:

# %% [markdown]
# ## and solar...

# %%
solar = states_with_plants[(states_with_plants['PrimSource'] == 'solar')]
# solar.plot(color='red')

# %%
no_solar = states_with_plants[(states_with_plants['PrimSource'] != 'solar')]
# no_solar.plot(color='darkgrey')

# %%
ax = states.plot(figsize=(20,20), color = 'lightgray', edgecolor = 'white')
# ax.axis('off')

solar.plot(ax=ax, color='red')
no_solar.plot(ax=ax, color='darkgrey', alpha=0.5)

ax.set_xlim([-130,-60])
ax.set_ylim([25,50])

# %% [markdown]
# ## 6. Make a map of carbon dioxide emissions by state, with low emissions being light orange and high emissions being orange.

# %%
states.head(1)

# %%
#create a new dataframe from the states geodataframe that has only the columns we want-the geometry and the stusps
states_with_geometry = states[['STUSPS', 'geometry']]
states_with_geometry.head()

# %%
#read in the co2 csv file
co2 = pd.read_csv('/Users/kaitlincough/Documents/Lede/foundation/14-homework-powerplants/Total Carbon Dioxide Emissions-StateRankings.csv')
co2.head(1)

# %%
#merge the csv file via and attribute join with the geodataframe that 
#has states and geometry
#get rid of annoying thigns

states_co2 = states_with_geometry.merge(co2, left_on='STUSPS', right_on='State')
del states_co2['Note: Rankings are based on the full source data values.']
del states_co2['State']
states_co2.head()

# %%
ax = states_co2.plot(column='Total Carbon Dioxide Emissions, million metric tons', cmap='OrRd', figsize=(50,50))
ax.set_xlim([-130,-60])
ax.set_ylim([25,50])

# %% [markdown]
# ## 6. Make a map of total energy produced by each state, with little being a light color and high emissions being a brighter/darker color.

# %%
powerplants[powerplants['source_des'].str.contains(r'(\d+)')]

# %% [markdown]
# ## 7. Make a map of total wind (or solar or coal) energy produced by each state, with little being a light color and high emissions being a brighter/darker color.

# %% [markdown]
# ## 8. Make a map of average air quality of each states, with high quality being light red and low quality being dark red

# %%
#use the arithmetic mean column, the 1st max datetime,
#columns to import: Latitude, Longitude, Datum, Arithmetic Mean, 1st Max Value, State name, County Name, City Name
airqual = pd.read_csv('/Users/kaitlincough/Documents/Lede/foundation/14-homework-powerplants/pm25_annual_fixed.csv', usecols = ['Latitude', 'Longitude', 'Datum', 'Arithmetic Mean', '1st Max Value', 'State Name', 'County Name', 'City Name'])
airqual.head()

# %%
#turn the airqual into a geodataframe
airqual = pd.read_csv('/Users/kaitlincough/Documents/Lede/foundation/14-homework-powerplants/pm25_annual_fixed.csv', usecols = ['Latitude', 'Longitude', 'Datum', 'Arithmetic Mean', '1st Max Value', 'State Name', 'County Name', 'City Name'])
points = airqual.apply(lambda row: Point(row.Longitude, row.Latitude), axis=1)
airqual = gpd.GeoDataFrame(airqual, geometry=points)
airqual.crs = {'init':'epsg:5070'}
airqual.head()

# %%
states.head()

# %%
#join it with states to get the staets polygons
#MAKE SURE YOU HAVE POLYGONS--to get them, you have to put the STATES df first
#that's the geometry it keeps
#use a left join to keep all the info
airqual_with_states = gpd.sjoin(states, airqual, how='left', op='contains')
airqual_with_states.head(2)

# %%
#plot the arithmetic mean column of the fancy new df

ax = airqual_with_states.plot(column='Arithmetic Mean', cmap='OrRd', figsize=(50,50))

ax.set_xlim([-130,-60])
ax.set_ylim([25,50])

# %% [markdown]
# ## 9. Make a map of worst air quality measured in each state, with high quality being light red and low quality being dark red

# %%
#same same but different

ax = airqual_with_states.plot(column='1st Max Value', cmap='OrRd', figsize=(50,50))

ax.set_xlim([-130,-60])
ax.set_ylim([25,50])

# %% [markdown]
# ## 10. Map of average PM2.5 measurement by county

# %%
airqual_with_states['County Name']

# %% [markdown]
# ## 11. Make a map with color coded power plants, and a 100 mile circle about major American cities.

# %% [markdown]
# ## 12. Which states have the most renewable plants, as a % of total plants? (include hydro, wind, solar)

# %% [markdown]
# ## 13. How many power plants are in each state

# %% [markdown]
# ## 14. powerplants_with_states = gpd.sjoin(powerplants, states, how='inner', op='within')
